# %%
import pandas as pd

# Load the Student Performance dataset
df = pd.read_csv("student_data.csv")

# Display first five records
print("Student Performance Dataset")
print(df.head())

# Group by age and calculate average grades
age_summary = df.groupby("age")[["G1", "G2", "G3"]].mean()

# Display the result
print("\nAverage Student Performance by Age")
print(age_summary)
# Out:
# Student Performance Dataset
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]
#
# Average Student Performance by Age
# ...

# %%
import pandas as pd

# Load student dataset
df = pd.read_csv("student_data.csv")

# Create Date column
df["Date"] = pd.date_range(
    start="2024-01-01",
    periods=len(df),
    freq="D"
)

# Set Date as index
df.set_index("Date", inplace=True)

# Down-sampling: Daily to Monthly
monthly_data = df.resample("M").mean(numeric_only=True)

print("Down-Sampled Monthly Data")
print(monthly_data)
# Out:
# Down-Sampled Monthly Data
#                   age      Medu      Fedu  traveltime  studytime  failures  \
# Date
# 2024-01-31  15.677419  3.161290  2.870968    1.258065   1.903226  0.258065
# 2024-02-29  15.310345  3.241379  2.827586    1.275862   1.896552  0.137931
# 2024-03-31  15.548387  2.838710  2.258065    1.419355   2.451613  0.258065
# 2024-04-30  15.533333  3.100000  2.866667    1.366667   2.200000  0.133333
# 2024-05-31  15.870968  2.451613  2.612903    1.516129   1.709677  0.806452
# 2024-06-30  16.366667  2.600000  2.466667    1.600000   1.666667  0.766667
# 2024-07-31  16.580645  2.548387  2.677419    1.258065   1.935484  0.161290
# 2024-08-31  16.935484  2.741935  2.387097    1.483871   2.000000  0.225806
# 2024-09-30  17.666667  2.533333  2.066667    1.433333   2.033333  0.300000
# 2024-10-31  17.645161  3.000000  2.451613    1.451613   2.225806  0.129032
# 2024-11-30  18.000000  2.500000  2.566667    1.366667   2.366667  0.333333
# ...

# %%
import pandas as pd

# Load student dataset
df = pd.read_csv("student_data.csv")

# Create Date column
df["Date"] = pd.date_range(
    start="2024-01-01",
    periods=len(df),
    freq="D"
)

# Set Date as index
df.set_index("Date", inplace=True)

# Down-sampling: Daily to Monthly
monthly_data = df.resample("M").mean(numeric_only=True)

# Up-sampling: Monthly to Daily
daily_data = monthly_data.resample("D").ffill()

print("Up-Sampled Daily Data")
print(daily_data.head(15))
# Out:
# Up-Sampled Daily Data
#                   age     Medu      Fedu  traveltime  studytime  failures  \
# Date
# 2024-01-31  15.677419  3.16129  2.870968    1.258065   1.903226  0.258065
# 2024-02-01  15.677419  3.16129  2.870968    1.258065   1.903226  0.258065
# 2024-02-02  15.677419  3.16129  2.870968    1.258065   1.903226  0.258065
# 2024-02-03  15.677419  3.16129  2.870968    1.258065   1.903226  0.258065
# 2024-02-04  15.677419  3.16129  2.870968    1.258065   1.903226  0.258065
# 2024-02-05  15.677419  3.16129  2.870968    1.258065   1.903226  0.258065
# 2024-02-06  15.677419  3.16129  2.870968    1.258065   1.903226  0.258065
# 2024-02-07  15.677419  3.16129  2.870968    1.258065   1.903226  0.258065
# 2024-02-08  15.677419  3.16129  2.870968    1.258065   1.903226  0.258065
# 2024-02-09  15.677419  3.16129  2.870968    1.258065   1.903226  0.258065
# 2024-02-10  15.677419  3.16129  2.870968    1.258065   1.903226  0.258065
# ...
